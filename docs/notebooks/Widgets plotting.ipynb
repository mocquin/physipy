# %%
# %matplotlib ipympl
from physipy import m, s
from physipy.qwidgets.plot_ui import WrappedFunction1D
from physipy.quantity.utils import name_eq

# %%
@name_eq("Myfunc")        
def func(x1, x2, x3):
    return x1*x2 + 3 * x3

wf = WrappedFunction1D(func, 0*s, 5*s, 
                       x2=(0*m, 5*m),
                       x3=(0*m*s, 5*m*s))

wf
# Out:
# HBox(children=(Output(), VBox(children=(QuantityTextSlider(value=<Quantity : 0 m, symbol=UndefinedSymbol*m>, c…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wf.add_integral(1*s, 4*s)

# %%
wf.x2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5k/bf4syt7x1zjbhc6b28srzzym0000gn/T/ipykernel_25712/1914507061.py in <module>
# ----> 1 wf.x2
#
# AttributeError: 'WrappedFunction1D' object has no attribute 'x2'
