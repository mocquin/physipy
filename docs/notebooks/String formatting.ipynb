# %% [markdown]
# # String formatting

# %%
import physipy
from physipy import m

# %%
q = 1.23456789*m

# %%
print(str(q))
# Out:
# 1.23456789 m

# %%
q._compute_value()
# Out:
# 1.23456789

# %% [markdown]
# ## Standard formatting

# %%
print(f"{q:.2f}")
print(f"{q:+.2f}")
print(f"{q:+9.2f}")
print(f"{q:*^15}")
print(f"{q: >-12.3f}")
# Out:
# 1.23 m
# +1.23 m
#     +1.23 m
# **1.23456789*** m
#        1.235 m

# %% [markdown]
# ## physipy formatting

# %%
print(f"{q}")
print(f"{q:~}")  # ~ : no prefix before unit
# Out:
# 1.23456789 m
# 1.23456789m
